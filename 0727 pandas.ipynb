# %%
import pandas as pd

# %%
df = pd.read_json('data2/data/nobel_winners_dirty.json')

# %%
df.info()   #갯수가 안맞을 때 처리 - 공란이 있는 데이터를 없애거나 채움(데이터를 정렬했을 때 가장 근접한 것 or 전체의 평균값 : interpolation)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1052 entries, 0 to 1051
# Data columns (total 12 columns):
# born_in           1052 non-null object
# category          1052 non-null object
# country           1052 non-null object
# date_of_birth     1044 non-null object
# date_of_death     1044 non-null object
# gender            1040 non-null object
# link              1052 non-null object
# name              1052 non-null object
# place_of_birth    1044 non-null object
# place_of_death    1044 non-null object
# text              1052 non-null object
# year              1052 non-null int64
# dtypes: int64(1), object(11)
# memory usage: 98.7+ KB

# %% [markdown]
# data type 종류
# - object(string)
# - int64
# - float64
# - datetime
# - category

# %% [markdown]
# gender : object -> 남:0 , 여:1 로 형 변환 가능(category)

# %%
df.describe(include='all') #숫자 데이터 외에 다른 컬럼에 관한 정보 출력
# Out:
#        born_in                category        country    date_of_birth  \
# count     1052                    1052           1052             1044
# unique      40                       7             59              853
# top             Physiology or Medicine  United States  7 November 1867
# freq       910                     250            350                4
# mean       NaN                     NaN            NaN              NaN
# std        NaN                     NaN            NaN              NaN
# min        NaN                     NaN            NaN              NaN
# 25%        NaN                     NaN            NaN              NaN
# 50%        NaN                     NaN            NaN              NaN
# 75%        NaN                     NaN            NaN              NaN
# max        NaN                     NaN            NaN              NaN
#
#        date_of_death gender                                         link  \
# ...

# %%
df.dtypes
# Out:
# born_in           object
# category          object
# country           object
# date_of_birth     object
# date_of_death     object
# gender            object
# link              object
# name              object
# place_of_birth    object
# place_of_death    object
# text              object
# year               int64
# dtype: object

# %%
df.shape
# Out:
# (1052, 12)

# %%
df
# Out:
#                      born_in                category    country  \
# 0                             Physiology or Medicine  Argentina
# 1     Bosnia and Herzegovina              Literature
# 2     Bosnia and Herzegovina               Chemistry
# 3                                              Peace    Belgium
# 4                                              Peace    Belgium
# 5                                         Literature    Belgium
# 6                                              Peace    Belgium
# 7                             Physiology or Medicine    Belgium
# 8                             Physiology or Medicine    Belgium
# 9                                              Peace    Belgium
# 10                            Physiology or Medicine    Belgium
# 11                            Physiology or Medicine    Belgium
# 12                                         Chemistry    Belgium
# 13                                           Physics    Belgium
# ...

# %%
df.describe(include=['object'])
# Out:
#        born_in                category        country    date_of_birth  \
# count     1052                    1052           1052             1044
# unique      40                       7             59              853
# top             Physiology or Medicine  United States  7 November 1867
# freq       910                     250            350                4
#
#        date_of_death gender                                         link  \
# count           1044   1040                                         1052
# unique           563      2                                          893
# top                    male  http://en.wikipedia.org/wiki/Michael_Levitt
# freq             362    982                                            4
#
#                     name place_of_birth place_of_death  \
# count               1052           1044           1044
# unique               998            735            410
# top     Frederick Sanger
# ...

# %%
df[df['category']=='Chemistry'].country.count()
# Out:
# 212

# %%
print(df[df['category']=='Chemistry'].country.unique())
len(df[df['category']=='Chemistry'].country.unique())
# Out:
# ['' 'Belgium' 'Denmark' 'Czech Republic' 'France' 'Germany' 'Israel'
#  'South Africa' 'United Kingdom' 'United States' 'Taiwan' 'Switzerland'
#  'Sweden' 'Russia' 'Poland' 'Norway' 'Netherlands' 'Japan' 'Italy'
#  'Hungary' 'Finland' 'Egypt' 'Canada' 'Austria' 'Argentina']
# 25

# %%
df.columns[0]
# Out:
# 'born_in'

# %%
df = df.set_index('name')  #덮어쓰는 방식은 좋지 않음. inplace=True 쓰지 않는 것이 좋다
df.head()
# Out:
#                                                 born_in  \
# name
# César Milstein
# Ivo Andric *                     Bosnia and Herzegovina
# Vladimir Prelog *                Bosnia and Herzegovina
# Institut de Droit International
# Auguste Beernaert
#
#                                                category    country  \
# name
# César Milstein                   Physiology or Medicine  Argentina
# Ivo Andric *                                 Literature
# Vladimir Prelog *                             Chemistry
# Institut de Droit International                   Peace    Belgium
# Auguste Beernaert                                 Peace    Belgium
#
#                                   date_of_birth   date_of_death gender  \
# name
# César Milstein                   8 October 1927   24 March 2002   male
# Ivo Andric *                     9 October 1892   13 March 1975   male
# Vladimir Prelog *                 July 23, 1906      1998-01-07   male
# ...

# %%
df.reset_index()
df.head()
# Out:
#                                                 born_in  \
# name
# César Milstein
# Ivo Andric *                     Bosnia and Herzegovina
# Vladimir Prelog *                Bosnia and Herzegovina
# Institut de Droit International
# Auguste Beernaert
#
#                                                category    country  \
# name
# César Milstein                   Physiology or Medicine  Argentina
# Ivo Andric *                                 Literature
# Vladimir Prelog *                             Chemistry
# Institut de Droit International                   Peace    Belgium
# Auguste Beernaert                                 Peace    Belgium
#
#                                   date_of_birth   date_of_death gender  \
# name
# César Milstein                   8 October 1927   24 March 2002   male
# Ivo Andric *                     9 October 1892   13 March 1975   male
# Vladimir Prelog *                 July 23, 1906      1998-01-07   male
# ...

# %%
bi_col = df.born_in
bi_col
# Out:
# name
# César Milstein
# Ivo Andric *                                       Bosnia and Herzegovina
# Vladimir Prelog *                                  Bosnia and Herzegovina
# Institut de Droit International
# Auguste Beernaert
# Maurice Maeterlinck
# Henri La Fontaine
# Jules Bordet
# Corneille Heymans
# Georges Pire
# Albert Claude
# Christian de Duve
# Ilya Prigogine
# François Englert
# Simon Kuznets *                                                   Belarus
# Menachem Begin *                                                  Belarus
# Shimon Peres *                                                    Belarus
# Karl Adolph Gjellerup
# August Krogh
# Niels Bohr
# Johannes Andreas Grib Fibiger
# Henrik Dam
# Johannes Vilhelm Jensen
# Ben Roy Mottelson
# Aage Bohr
# Niels Kaj Jerne
# Jens Christian Skou
# Bertha von Suttner *                                       Czech Republic
# Gerty Cori *                                               Czech Republic
# ...

# %%
df.set_index('name', drop=True, inplace = True)

# %%
df.iloc[0]
# Out:
# born_in
# category                                    Physiology or Medicine
# country                                                  Argentina
# date_of_birth                                       8 October 1927
# date_of_death                                        24 March 2002
# gender                                                        male
# link              http://en.wikipedia.org/wiki/C%C3%A9sar_Milstein
# place_of_birth                           Bahía Blanca ,  Argentina
# place_of_death                                 Cambridge , England
# text                 César Milstein , Physiology or Medicine, 1984
# year                                                          1984
# Name: César Milstein, dtype: object

# %%
df.loc[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-7eaf75073732> in <module>()
# ----> 1 df.loc[0]
#
# C:\anaconda\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1476
#    1477             maybe_callable = com._apply_if_callable(key, self.obj)
# -> 1478             return self._getitem_axis(maybe_callable, axis=axis)
#    1479
#    1480     def _is_scalar_access(self, key):
#
# C:\anaconda\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1909
#    1910         # fall thru to straight lookup
# -> 1911         self._validate_key(key, axis)
#    1912         return self._get_label(key, axis=axis)
#    1913
#
# C:\anaconda\lib\site-packages\pandas\core\indexing.py in _validate_key(self, key, axis)
#    1786
#    1787             try:
# -> 1788                 key = self._convert_scalar_indexer(key, axis)
# ...

# %%
df.loc['César Milstein']
# Out:
#                born_in                category         country  \
# name
# César Milstein          Physiology or Medicine       Argentina
# César Milstein          Physiology or Medicine  United Kingdom
#
#                  date_of_birth  date_of_death gender  \
# name
# César Milstein  8 October 1927  24 March 2002   male
# César Milstein  8 October 1927  24 March 2002   male
#
#                                                             link  \
# name
# César Milstein  http://en.wikipedia.org/wiki/C%C3%A9sar_Milstein
# César Milstein  http://en.wikipedia.org/wiki/C%C3%A9sar_Milstein
#
#                            place_of_birth       place_of_death  \
# name
# César Milstein  Bahía Blanca ,  Argentina  Cambridge , England
# César Milstein  Bahía Blanca ,  Argentina  Cambridge , England
#
#                                                              text  year
# name
# César Milstein      César Milstein , Physiology or Medicine, 1984  1984
# ...

# %%
mask = df.year > 2000
winners_since_2000 = df[mask]
winners_since_2000.count()
# Out:
# born_in           202
# category          202
# country           202
# date_of_birth     201
# date_of_death     201
# gender            200
# link              202
# place_of_birth    201
# place_of_death    201
# text              202
# year              202
# dtype: int64

# %%
df.reset_index(inplace = True)

# %%
df.born_in.head(10)
# Out:
# 0
# 1    Bosnia and Herzegovina
# 2    Bosnia and Herzegovina
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# Name: born_in, dtype: object

# %%
df.born_in.apply(type) #series.apply(함수명) : series의 각 row에 해당 함수를 적용  - 함수형 패러다임
# Out:
# 0       <class 'str'>
# 1       <class 'str'>
# 2       <class 'str'>
# 3       <class 'str'>
# 4       <class 'str'>
# 5       <class 'str'>
# 6       <class 'str'>
# 7       <class 'str'>
# 8       <class 'str'>
# 9       <class 'str'>
# 10      <class 'str'>
# 11      <class 'str'>
# 12      <class 'str'>
# 13      <class 'str'>
# 14      <class 'str'>
# 15      <class 'str'>
# 16      <class 'str'>
# 17      <class 'str'>
# 18      <class 'str'>
# 19      <class 'str'>
# 20      <class 'str'>
# 21      <class 'str'>
# 22      <class 'str'>
# 23      <class 'str'>
# 24      <class 'str'>
# 25      <class 'str'>
# 26      <class 'str'>
# 27      <class 'str'>
# 28      <class 'str'>
# 29      <class 'str'>
#             ...
# 1022    <class 'str'>
# 1023    <class 'str'>
# 1024    <class 'str'>
# 1025    <class 'str'>
# 1026    <class 'str'>
# 1027    <class 'str'>
# 1028    <class 'str'>
# 1029    <class 'str'>
# 1030    <class 'str'>
# 1031    <class 'str'>
# ...

# %%
df.born_in.map(len)  #map은 series에서만 사용가능, apply는 series와 data frame 에 모두 사용가능
# Out:
# 0       <class 'str'>
# 1       <class 'str'>
# 2       <class 'str'>
# 3       <class 'str'>
# 4       <class 'str'>
# 5       <class 'str'>
# 6       <class 'str'>
# 7       <class 'str'>
# 8       <class 'str'>
# 9       <class 'str'>
# 10      <class 'str'>
# 11      <class 'str'>
# 12      <class 'str'>
# 13      <class 'str'>
# 14      <class 'str'>
# 15      <class 'str'>
# 16      <class 'str'>
# 17      <class 'str'>
# 18      <class 'str'>
# 19      <class 'str'>
# 20      <class 'str'>
# 21      <class 'str'>
# 22      <class 'str'>
# 23      <class 'str'>
# 24      <class 'str'>
# 25      <class 'str'>
# 26      <class 'str'>
# 27      <class 'str'>
# 28      <class 'str'>
# 29      <class 'str'>
#             ...
# 1022    <class 'str'>
# 1023    <class 'str'>
# 1024    <class 'str'>
# 1025    <class 'str'>
# 1026    <class 'str'>
# 1027    <class 'str'>
# 1028    <class 'str'>
# 1029    <class 'str'>
# 1030    <class 'str'>
# 1031    <class 'str'>
# ...

# %%
def unknown(row):
    if not len(row):
        return 'unknown'
    else:
        return row
df.born_in = df.born_in.map(unknown)

# %%
df.head()
# Out:
#                               name                 born_in  \
# 0                   César Milstein                 unknown
# 1                     Ivo Andric *  Bosnia and Herzegovina
# 2                Vladimir Prelog *  Bosnia and Herzegovina
# 3  Institut de Droit International                 unknown
# 4                Auguste Beernaert                 unknown
#
#                  category    country   date_of_birth   date_of_death gender  \
# 0  Physiology or Medicine  Argentina  8 October 1927   24 March 2002   male
# 1              Literature             9 October 1892   13 March 1975   male
# 2               Chemistry              July 23, 1906      1998-01-07   male
# 3                   Peace    Belgium            None            None   None
# 4                   Peace    Belgium    26 July 1829  6 October 1912   male
#
#                                                 link  \
# 0   http://en.wikipedia.org/wiki/C%C3%A9sar_Milstein
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1052 entries, 0 to 1051
# Data columns (total 12 columns):
# name              1052 non-null object
# born_in           1052 non-null object
# category          1052 non-null object
# country           1052 non-null object
# date_of_birth     1044 non-null object
# date_of_death     1044 non-null object
# gender            1040 non-null object
# link              1052 non-null object
# place_of_birth    1044 non-null object
# place_of_death    1044 non-null object
# text              1052 non-null object
# year              1052 non-null int64
# dtypes: int64(1), object(11)
# memory usage: 98.7+ KB

# %%
bi_col = df.born_in
bi_col
# Out:
# 0                      unknown
# 1       Bosnia and Herzegovina
# 2       Bosnia and Herzegovina
# 3                      unknown
# 4                      unknown
# 5                      unknown
# 6                      unknown
# 7                      unknown
# 8                      unknown
# 9                      unknown
# 10                     unknown
# 11                     unknown
# 12                     unknown
# 13                     unknown
# 14                     Belarus
# 15                     Belarus
# 16                     Belarus
# 17                     unknown
# 18                     unknown
# 19                     unknown
# 20                     unknown
# 21                     unknown
# 22                     unknown
# 23                     unknown
# 24                     unknown
# 25                     unknown
# 26                     unknown
# 27              Czech Republic
# 28              Czech Republic
# 29              Czech Republic
# ...

# %%
import numpy as np

# %%
bi_col.replace('unknown', np.nan, inplace=True)    #np.nan : NaN값으로 만들어 줌 - Not available Number

# %%
df.head()
# Out:
#                               name                 born_in  \
# 0                   César Milstein                     NaN
# 1                     Ivo Andric *  Bosnia and Herzegovina
# 2                Vladimir Prelog *  Bosnia and Herzegovina
# 3  Institut de Droit International                     NaN
# 4                Auguste Beernaert                     NaN
#
#                  category    country   date_of_birth   date_of_death gender  \
# 0  Physiology or Medicine  Argentina  8 October 1927   24 March 2002   male
# 1              Literature             9 October 1892   13 March 1975   male
# 2               Chemistry              July 23, 1906      1998-01-07   male
# 3                   Peace    Belgium            None            None   None
# 4                   Peace    Belgium    26 July 1829  6 October 1912   male
#
#                                                 link  \
# 0   http://en.wikipedia.org/wiki/C%C3%A9sar_Milstein
# ...

# %%
name_col = df[df.name.str.contains('\*')].name

# %%
# df[df.name.str.contains('\*')].name = name_col.str.replace('*','')
name_col.replace('\*','', inplace=True)
df.name.str.strip()
# Out:
# C:\anaconda\lib\site-packages\pandas\core\generic.py:5890: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# 0                                        César Milstein
# 1                                          Ivo Andric *
# 2                                     Vladimir Prelog *
# 3                       Institut de Droit International
# 4                                     Auguste Beernaert
# 5                                   Maurice Maeterlinck
# 6                                     Henri La Fontaine
# 7                                          Jules Bordet
# 8                                     Corneille Heymans
# 9                                          Georges Pire
# 10                                        Albert Claude
# ...

# %%
df.head()
# Out:
#                               name                 born_in  \
# 0                   César Milstein                     NaN
# 1                     Ivo Andric *  Bosnia and Herzegovina
# 2                Vladimir Prelog *  Bosnia and Herzegovina
# 3  Institut de Droit International                     NaN
# 4                Auguste Beernaert                     NaN
#
#                  category    country   date_of_birth   date_of_death gender  \
# 0  Physiology or Medicine  Argentina  8 October 1927   24 March 2002   male
# 1              Literature             9 October 1892   13 March 1975   male
# 2               Chemistry              July 23, 1906      1998-01-07   male
# 3                   Peace    Belgium            None            None   None
# 4                   Peace    Belgium    26 July 1829  6 October 1912   male
#
#                                                 link  \
# 0   http://en.wikipedia.org/wiki/C%C3%A9sar_Milstein
# ...

# %%
np.nan == np.nan
# Out:
# False

# %%
None == False
# Out:
# False

# %%
df.born_in.isnull()
# Out:
# 0        True
# 1       False
# 2       False
# 3        True
# 4        True
# 5        True
# 6        True
# 7        True
# 8        True
# 9        True
# 10       True
# 11       True
# 12       True
# 13       True
# 14      False
# 15      False
# 16      False
# 17       True
# 18       True
# 19       True
# 20       True
# 21       True
# 22       True
# 23       True
# 24       True
# 25       True
# 26       True
# 27      False
# 28      False
# 29      False
#         ...
# 1022     True
# 1023    False
# 1024    False
# 1025     True
# 1026     True
# 1027    False
# 1028     True
# 1029     True
# 1030    False
# 1031    False
# 1032     True
# 1033     True
# 1034    False
# 1035    False
# 1036     True
# 1037     True
# 1038     True
# 1039    False
# 1040     True
# 1041    False
# 1042     True
# 1043     True
# 1044     True
# 1045     True
# 1046    False
# 1047     True
# 1048     True
# 1049     True
# 1050     True
# 1051     True
# ...

# %%
df.born_in.isna()  #nan
# Out:
# 0        True
# 1       False
# 2       False
# 3        True
# 4        True
# 5        True
# 6        True
# 7        True
# 8        True
# 9        True
# 10       True
# 11       True
# 12       True
# 13       True
# 14      False
# 15      False
# 16      False
# 17       True
# 18       True
# 19       True
# 20       True
# 21       True
# 22       True
# 23       True
# 24       True
# 25       True
# 26       True
# 27      False
# 28      False
# 29      False
#         ...
# 1022     True
# 1023    False
# 1024    False
# 1025     True
# 1026     True
# 1027    False
# 1028     True
# 1029     True
# 1030    False
# 1031    False
# 1032     True
# 1033     True
# 1034    False
# 1035    False
# 1036     True
# 1037     True
# 1038     True
# 1039    False
# 1040     True
# 1041    False
# 1042     True
# 1043     True
# 1044     True
# 1045     True
# 1046    False
# 1047     True
# 1048     True
# 1049     True
# 1050     True
# 1051     True
# ...

# %% [markdown]
# 필요없는 값(*) 지우고 없는 값 채워놓기 / 없는 값 버릴 때는 drop
# : data cleaning

# %%
df.dropna()
# Out:
#                                name                 born_in  \
# 1                      Ivo Andric *  Bosnia and Herzegovina
# 2                 Vladimir Prelog *  Bosnia and Herzegovina
# 14                  Simon Kuznets *                 Belarus
# 15                 Menachem Begin *                 Belarus
# 16                   Shimon Peres *                 Belarus
# 27             Bertha von Suttner *          Czech Republic
# 28                     Gerty Cori *          Czech Republic
# 29            Carl Ferdinand Cori *          Czech Republic
# 50                Henry Kissinger *                 Germany
# 51                   Arno Penzias *                 Germany
# 53            Georges J.F. Köhler *                 Germany
# 58               Jack Steinberger *                 Germany
# 63                Hans G. Dehmelt *                 Germany
# 82                Renato Dulbecco *                   Italy
# 87              Riccardo Giacconi *                   Italy
# ...

# %% [markdown]
# 중복값 처리 - duplicated

# %%
df.duplicated('name')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 1022    False
# 1023    False
# 1024    False
# 1025    False
# 1026    False
# 1027    False
# 1028    False
# 1029     True
# 1030    False
# 1031    False
# 1032    False
# 1033    False
# 1034    False
# 1035    False
# 1036    False
# 1037    False
# 1038    False
# 1039    False
# 1040    False
# 1041    False
# 1042    False
# 1043    False
# 1044    False
# 1045    False
# 1046    False
# 1047     True
# 1048    False
# 1049    False
# 1050    False
# 1051    False
# ...

# %%
df.name.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 1022    False
# 1023    False
# 1024    False
# 1025    False
# 1026    False
# 1027    False
# 1028    False
# 1029     True
# 1030    False
# 1031    False
# 1032    False
# 1033    False
# 1034    False
# 1035    False
# 1036    False
# 1037    False
# 1038    False
# 1039    False
# 1040    False
# 1041    False
# 1042    False
# 1043    False
# 1044    False
# 1045    False
# 1046    False
# 1047     True
# 1048    False
# 1049    False
# 1050    False
# 1051    False
# ...

# %%
df.duplicated('name')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 1022    False
# 1023    False
# 1024    False
# 1025    False
# 1026    False
# 1027    False
# 1028    False
# 1029     True
# 1030    False
# 1031    False
# 1032    False
# 1033    False
# 1034    False
# 1035    False
# 1036    False
# 1037    False
# 1038    False
# 1039    False
# 1040    False
# 1041    False
# 1042    False
# 1043    False
# 1044    False
# 1045    False
# 1046    False
# 1047     True
# 1048    False
# 1049    False
# 1050    False
# 1051    False
# ...

# %%
all_dupes = df[df.duplicated('name') \
| df.duplicated('name', keep='last')]
all_dupes.count()
# Out:
# name              108
# born_in            16
# category          108
# country           108
# date_of_birth     106
# date_of_death     106
# gender            104
# link              108
# place_of_birth    106
# place_of_death    106
# text              108
# year              108
# dtype: int64

# %%
df.drop_duplicates()
# Out:
#                                                  name                 born_in  \
# 0                                      César Milstein                     NaN
# 1                                        Ivo Andric *  Bosnia and Herzegovina
# 2                                   Vladimir Prelog *  Bosnia and Herzegovina
# 3                     Institut de Droit International                     NaN
# 4                                   Auguste Beernaert                     NaN
# 5                                 Maurice Maeterlinck                     NaN
# 6                                   Henri La Fontaine                     NaN
# 7                                        Jules Bordet                     NaN
# 8                                   Corneille Heymans                     NaN
# 9                                        Georges Pire                     NaN
# 10                                      Albert Claude                     NaN
# ...

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [born_in, category, country, date_of_birth, date_of_death, gender, link, name, place_of_birth, place_of_death, text, year]
# Index: []

# %%
dupes_by_name = df.duplicated('name')
all_dupes = df[df.name.isin(dupes_by_name)]

# %% [markdown]
# 종교별 연간수입 데이터

# %%
data
# Out:
#                    religion  <$10k  $10-20k  $20-30k  $30-40k  $40-50k  \
# 0                  Agnostic     27       34       60       81       76
# 1                   Atheist     12       27       37       52       35
# 2                  Buddhist     27       21       30       34       33
# 3                  Catholic    418      617      732      670      638
# 4        Don’t know/refused     15       14       15       11       10
# 5          Evangelical Prot    575      869     1064      982      881
# 6                     Hindu      1        9        7        9       11
# 7   Historically Black Prot    228      244      236      238      197
# 8         Jehovah's Witness     20       27       24       24       21
# 9                    Jewish     19       19       25       25       30
# 10            Mainline Prot    289      495      619      655      651
# 11                   Mormon     29       40       48       51       56
# ...

# %%
data = pd.read_csv('data1/data/pew.txt', sep='\t')

# %%
data[data.religion=='Buddhist'].mean(axis=1)
# Out:
# 2    41.1
# dtype: float64

# %% [markdown]
# tidy data로 변환해서 분석하기 좋은 형태로 만들어주는 것이 중요(reshape)
# > wide format을 long format으로 변환한 후 groupby로 통계 파악

# %%
melt_data = data.melt('religion') #wide format 을 long format으로 변환 - column명에 변수적 개념이 있는 데이터가 있을 때 유용

# %%
melt_data[melt_data.religion=='Hindu']
# Out:
#     religion            variable  value
# 6      Hindu               <$10k      1
# 24     Hindu             $10-20k      9
# 42     Hindu             $20-30k      7
# 60     Hindu             $30-40k      9
# 78     Hindu             $40-50k     11
# 96     Hindu             $50-75k     34
# 114    Hindu            $75-100k     47
# 132    Hindu           $100-150k     48
# 150    Hindu               >150k     54
# 168    Hindu  Don't know/refused     37

# %%
melt_data.groupby('religion').mean()
# Out:
#                          value
# religion
# Agnostic                  82.6
# Atheist                   51.5
# Buddhist                  41.1
# Catholic                 805.4
# Don’t know/refused        27.2
# Evangelical Prot         947.2
# Hindu                     25.7
# Historically Black Prot  199.5
# Jehovah's Witness         21.5
# Jewish                    68.2
# Mainline Prot            747.0
# Mormon                    58.1
# Muslim                    11.6
# Orthodox                  36.3
# Other Christian           12.9
# Other Faiths              44.9
# Other World Religions      4.2
# Unaffiliated             370.7

# %%
data = pd.read_csv('data1/data/tb.csv')

# %%
data
# Out:
#      iso2  year   new_sp  new_sp_m04  new_sp_m514  new_sp_m014  new_sp_m1524  \
# 0      AD  1989      NaN         NaN          NaN          NaN           NaN
# 1      AD  1990      NaN         NaN          NaN          NaN           NaN
# 2      AD  1991      NaN         NaN          NaN          NaN           NaN
# 3      AD  1992      NaN         NaN          NaN          NaN           NaN
# 4      AD  1993     15.0         NaN          NaN          NaN           NaN
# 5      AD  1994     24.0         NaN          NaN          NaN           NaN
# 6      AD  1996      8.0         NaN          NaN          0.0           0.0
# 7      AD  1997     17.0         NaN          NaN          0.0           0.0
# 8      AD  1998      1.0         NaN          NaN          0.0           0.0
# 9      AD  1999      4.0         NaN          NaN          0.0           0.0
# 10     AD  2000      1.0         NaN          NaN          0.0           0.0
# ...

# %%
data = data.melt(['iso2','year'], value_name='y', var_name='x')

# %%
data.dropna(inplace=True)

# %%
data
# Out:
#        iso2  year          x       y
# 4        AD  1993     new_sp    15.0
# 5        AD  1994     new_sp    24.0
# 6        AD  1996     new_sp     8.0
# 7        AD  1997     new_sp    17.0
# 8        AD  1998     new_sp     1.0
# 9        AD  1999     new_sp     4.0
# 10       AD  2000     new_sp     1.0
# 11       AD  2001     new_sp     3.0
# 12       AD  2002     new_sp     2.0
# 13       AD  2003     new_sp     7.0
# 14       AD  2004     new_sp     3.0
# 15       AD  2005     new_sp     5.0
# 16       AD  2006     new_sp     8.0
# 17       AD  2007     new_sp     2.0
# 18       AD  2008     new_sp     3.0
# 35       AE  1999     new_sp    31.0
# 36       AE  2000     new_sp    73.0
# 37       AE  2001     new_sp    69.0
# 38       AE  2002     new_sp    57.0
# 39       AE  2003     new_sp    77.0
# 40       AE  2004     new_sp    57.0
# 41       AE  2005     new_sp    62.0
# 42       AE  2006     new_sp    52.0
# 43       AE  2007     new_sp    56.0
# ...

# %%
data.groupby(['iso2', 'year']).sum()    #multi-index
# Out:
#                   y
# iso2 year
# AD   1993      15.0
#      1994      24.0
#      1996      16.0
#      1997      36.0
#      1998       2.0
#      1999       7.0
#      2000       2.0
#      2001       6.0
#      2002       4.0
#      2003      13.0
#      2004       6.0
#      2005      10.0
#      2006      16.0
#      2007       4.0
#      2008       6.0
# AE   1999      97.0
#      2000     143.0
#      2001      69.0
#      2002     114.0
#      2003     154.0
#      2004     114.0
#      2005      62.0
#      2006     106.0
#      2007     112.0
#      2008     100.0
# AF   1997     746.0
#      1998    3611.0
#      1999    2414.0
#      2000    5558.0
#      2001    9278.0
# ...             ...
# ZA   2007  273329.0
#      2008  281829.0
# ZM   1994    9620.0
#      1995   18615.0
#      1996   12072.0
#      1999   11645.0
#      2000   25854.0
#      2001   13024.0
#      2002   32702.0
#      2003   37868.0
#      2004   34494.0
#      2005   29714.0
# ...

# %%
data_w = pd.read_csv('data1/data/weather.txt', sep='\t')

# %%
data_w
# Out:
#              id  year  month element     d1     d2     d3     d4     d5  \
# 0   MX000017004  2010      1    TMAX    NaN    NaN    NaN    NaN    NaN
# 1   MX000017004  2010      1    TMIN    NaN    NaN    NaN    NaN    NaN
# 2   MX000017004  2010      2    TMAX    NaN  273.0  241.0    NaN    NaN
# 3   MX000017004  2010      2    TMIN    NaN  144.0  144.0    NaN    NaN
# 4   MX000017004  2010      3    TMAX    NaN    NaN    NaN    NaN  321.0
# 5   MX000017004  2010      3    TMIN    NaN    NaN    NaN    NaN  142.0
# 6   MX000017004  2010      4    TMAX    NaN    NaN    NaN    NaN    NaN
# 7   MX000017004  2010      4    TMIN    NaN    NaN    NaN    NaN    NaN
# 8   MX000017004  2010      5    TMAX    NaN    NaN    NaN    NaN    NaN
# 9   MX000017004  2010      5    TMIN    NaN    NaN    NaN    NaN    NaN
# 10  MX000017004  2010      6    TMAX    NaN    NaN    NaN    NaN    NaN
# 11  MX000017004  2010      6    TMIN    NaN    NaN    NaN    NaN    NaN
# ...

# %%
data_w = data_w.melt(['id','year','month','element'])

# %%
data_w.id.unique()
# Out:
# array(['MX000017004'], dtype=object)

# %%
del data_w['id']

# %%
data_w
# Out:
#      year  month element variable  value
# 0    2010      1    TMAX       d1    NaN
# 1    2010      1    TMIN       d1    NaN
# 2    2010      2    TMAX       d1    NaN
# 3    2010      2    TMIN       d1    NaN
# 4    2010      3    TMAX       d1    NaN
# 5    2010      3    TMIN       d1    NaN
# 6    2010      4    TMAX       d1    NaN
# 7    2010      4    TMIN       d1    NaN
# 8    2010      5    TMAX       d1    NaN
# 9    2010      5    TMIN       d1    NaN
# 10   2010      6    TMAX       d1    NaN
# 11   2010      6    TMIN       d1    NaN
# 12   2010      7    TMAX       d1    NaN
# 13   2010      7    TMIN       d1    NaN
# 14   2010      8    TMAX       d1    NaN
# 15   2010      8    TMIN       d1    NaN
# 16   2010     10    TMAX       d1    NaN
# 17   2010     10    TMIN       d1    NaN
# 18   2010     11    TMAX       d1    NaN
# 19   2010     11    TMIN       d1    NaN
# 20   2010     12    TMAX       d1  299.0
# 21   2010     12    TMIN       d1  138.0
# ...

# %%
data_w.dropna()
# Out:
#      year  month element variable  value
# 20   2010     12    TMAX       d1  299.0
# 21   2010     12    TMIN       d1  138.0
# 24   2010      2    TMAX       d2  273.0
# 25   2010      2    TMIN       d2  144.0
# 40   2010     11    TMAX       d2  313.0
# 41   2010     11    TMIN       d2  163.0
# 46   2010      2    TMAX       d3  241.0
# 47   2010      2    TMIN       d3  144.0
# 56   2010      7    TMAX       d3  286.0
# 57   2010      7    TMIN       d3  175.0
# 84   2010     11    TMAX       d4  272.0
# 85   2010     11    TMIN       d4  120.0
# 92   2010      3    TMAX       d5  321.0
# 93   2010      3    TMIN       d5  142.0
# 102  2010      8    TMAX       d5  296.0
# 103  2010      8    TMIN       d5  158.0
# 104  2010     10    TMAX       d5  270.0
# 105  2010     10    TMIN       d5  140.0
# 106  2010     11    TMAX       d5  263.0
# 107  2010     11    TMIN       d5   79.0
# 130  2010     12    TMAX       d6  278.0
# 131  2010     12    TMIN       d6  105.0
# ...

# %%
data_w.reset_index(drop=True)
# Out:
#      year  month element variable  value
# 0    2010      1    TMAX       d1    NaN
# 1    2010      1    TMIN       d1    NaN
# 2    2010      2    TMAX       d1    NaN
# 3    2010      2    TMIN       d1    NaN
# 4    2010      3    TMAX       d1    NaN
# 5    2010      3    TMIN       d1    NaN
# 6    2010      4    TMAX       d1    NaN
# 7    2010      4    TMIN       d1    NaN
# 8    2010      5    TMAX       d1    NaN
# 9    2010      5    TMIN       d1    NaN
# 10   2010      6    TMAX       d1    NaN
# 11   2010      6    TMIN       d1    NaN
# 12   2010      7    TMAX       d1    NaN
# 13   2010      7    TMIN       d1    NaN
# 14   2010      8    TMAX       d1    NaN
# 15   2010      8    TMIN       d1    NaN
# 16   2010     10    TMAX       d1    NaN
# 17   2010     10    TMIN       d1    NaN
# 18   2010     11    TMAX       d1    NaN
# 19   2010     11    TMIN       d1    NaN
# 20   2010     12    TMAX       d1  299.0
# 21   2010     12    TMIN       d1  138.0
# ...

# %%
data_w = data_w[['year','month','element','variable','value']]  #sorting

# %%
data_w
# Out:
#      year  month element variable  value
# 0    2010      1    TMAX       d1    NaN
# 1    2010      1    TMIN       d1    NaN
# 2    2010      2    TMAX       d1    NaN
# 3    2010      2    TMIN       d1    NaN
# 4    2010      3    TMAX       d1    NaN
# 5    2010      3    TMIN       d1    NaN
# 6    2010      4    TMAX       d1    NaN
# 7    2010      4    TMIN       d1    NaN
# 8    2010      5    TMAX       d1    NaN
# 9    2010      5    TMIN       d1    NaN
# 10   2010      6    TMAX       d1    NaN
# 11   2010      6    TMIN       d1    NaN
# 12   2010      7    TMAX       d1    NaN
# 13   2010      7    TMIN       d1    NaN
# 14   2010      8    TMAX       d1    NaN
# 15   2010      8    TMIN       d1    NaN
# 16   2010     10    TMAX       d1    NaN
# 17   2010     10    TMIN       d1    NaN
# 18   2010     11    TMAX       d1    NaN
# 19   2010     11    TMIN       d1    NaN
# 20   2010     12    TMAX       d1  299.0
# 21   2010     12    TMIN       d1  138.0
# ...

# %%
data_w = data_w.sort_values('month').reset_index(drop=True)

# %%
data_w[data_w['element']=='TMIN'].groupby('month').mean()
# Out:
#        year       value
# month
# 1      2010  145.000000
# 2      2010  132.250000
# 3      2010  162.000000
# 4      2010  167.000000
# 5      2010  182.000000
# 6      2010  177.500000
# 7      2010  170.000000
# 8      2010  158.428571
# 10     2010  130.800000
# 11     2010  125.000000
# 12     2010  121.500000

# %%
data_w.pivot_table(index='month', values='value')
# Out:
#             value
# month
# 1      211.500000
# 2      204.875000
# 3      243.833333
# 4      265.000000
# 5      257.000000
# 6      234.000000
# 7      231.250000
# 8      220.571429
# 10     209.900000
# 11     203.100000
# 12     205.000000

# %%
pd.pivot_table(data_w, index='month', values='value')
# Out:
#             value
# month
# 1      211.500000
# 2      204.875000
# 3      243.833333
# 4      265.000000
# 5      257.000000
# 6      234.000000
# 7      231.250000
# 8      220.571429
# 10     209.900000
# 11     203.100000
# 12     205.000000

# %%
data_w.groupby('month').mean()
# Out:
#        year       value
# month
# 1      2010  211.500000
# 2      2010  204.875000
# 3      2010  243.833333
# 4      2010  265.000000
# 5      2010  257.000000
# 6      2010  234.000000
# 7      2010  231.250000
# 8      2010  220.571429
# 10     2010  209.900000
# 11     2010  203.100000
# 12     2010  205.000000

# %%
data_w.groupby('month').mean()
# Out:
#        year     d1     d2     d3     d4     d5     d6     d7     d8  d9  \
# month
# 1      2010    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN NaN
# 2      2010    NaN  208.5  192.5    NaN    NaN    NaN    NaN    NaN NaN
# 3      2010    NaN    NaN    NaN    NaN  231.5    NaN    NaN    NaN NaN
# 4      2010    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN NaN
# 5      2010    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN NaN
# 6      2010    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN NaN
# 7      2010    NaN    NaN  230.5    NaN    NaN    NaN    NaN    NaN NaN
# 8      2010    NaN    NaN    NaN    NaN  227.0    NaN    NaN  231.5 NaN
# 10     2010    NaN    NaN    NaN    NaN  205.0    NaN  205.0    NaN NaN
# 11     2010    NaN  238.0    NaN  196.0  171.0    NaN    NaN    NaN NaN
# 12     2010  218.5    NaN    NaN    NaN    NaN  191.5    NaN    NaN NaN
#
#        ...    d22    d23  d24    d25    d26    d27    d28    d29    d30    d31
# month  ...
# ...
